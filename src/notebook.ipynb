# %%
# %load_ext autoreload
# %autoreload 2

# %%
from ATST.ATST import read_atst


file_data = read_atst("../examples/example_3.atst.txt")

# %%
file_data.OD600_3.layout.data
# Out:
#   well_loc       linked_file
# 0           layout_00003.tsv
